# %% [markdown]
# # Initializing setup to practice

# %% [markdown]
# Connected data source in catelogue(uploaded data)

# %%
# %sql

SELECT *
FROM csv.`/Volumes/workspace/default/practice_employess/jobs_in_data.csv`

# %% [markdown]
# using spark to read the data

# %%
df = spark.table('employess')
df.display()

# %%
df1 = spark.read.csv('/Volumes/workspace/default/practice_employess/jobs_in_data.csv',
                     header=True,
                     inferSchema=True)

# %%
df1.display()

# %% [markdown]
# ### working on sample data in build

# %%
# %sql
SHOW DATABASES

# %%
# %sql
SHOW CATALOGS

# %%
# %sql
USE CATALOG samples

# %%
# %sql

SHOW DATABASES

# %%
# %sql
USE DATABASE bakehouse

# %%
# %sql

SHOW TABLES

# %%
# %sql

DESCRIBE DETAIL samples.bakehouse.sales_transactions

# %%
# %sql
SELECT * FROM sales_transactions

# %%
from pyspark.sql.functions import col
tables_names = [row.tableName for row in spark.sql("SHOW TABLES").select("tableName").select("tableName").collect()]
tables_names

# %%
for i in tables_names:
    print(f"Table name is: {i}")
    spark.sql(f"SELECT * FROM {i} LIMIT 10").display()
